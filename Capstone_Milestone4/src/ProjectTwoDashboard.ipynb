# %%
# Configure the necessary Python module imports for dashboard components
from dash import Dash, dcc, html, dash_table, Input, Output, State
import dash_leaflet as dl
import plotly.express as px
import base64

# Configure the plotting routines
import pandas as pd

import Project_One as AAC

###########################
# Data Manipulation / Model
###########################

# Connect to database with the CRUD model by creating an instance
db = AAC.AnimalShelter()

# class read method must support return of list object and accept projection JSON input
# sending the read method an empty document requests all documents be returned
df = pd.DataFrame.from_records(db.read({}))

# MongoDB v5+ is going to return the "_id" column and that is going to have an 
# invlaid object type of "ObjectID" - which will cause the data_table to crash - so we remove
# it in the dataframe here. The df.drop command allows us to drop the column. If we do not set
# inplace=True - it will reeturn a new dataframe that does not contain the dropped column(s)
if "_id" in df.columns:
    df.drop(columns=["_id"], inplace=True, errors="ignore")


#########################
# Dashboard Layout / View
#########################
app = Dash(__name__)

# logo img path
image_filename = "./Grazioso Salvare Logo.png"
encoded_image = base64.b64encode(open(image_filename, "rb").read())

# get unique breeds and sort them alphabetically for the first load of the breed filter
breeds = [breed for breed in df['breed'].unique()]
breeds.sort()
breeds.insert(0, 'No Filter')


app.layout = [
    html.Div(children=[
# Logo
    dcc.Link(
        html.Img(src="data:image/png;base64,{}".format(encoded_image.decode()),
                 alt="Grazioso Logo", height="200", width="200"),
                href="snhu.edu"),

# Title and Header
    html.B(html.H3("CS-340 Dashboard")),
    html.H3("Alec Novak - SNHU"),
    html.Hr(),


# Filter Options grouped in Divs, all Divs nested within this Div
    html.Div(
        className="filters",
        style={'display': 'flex', 'width' : '100%'},
        children=[
             
# Animal Type Filter using Radio selector
        html.Div(
            style={'display' : 'block', 'flex': '20%', 'border-left' : '4px solid black'},
            children=[
            html.Center(html.H2("Filter by Animal Type:", style={'display' : 'block'})),
            dcc.RadioItems(
                options=['No Filter', 'Dog', 'Cat', 'Other'],
                value='No Filter',
                id='animal_filter',
                ),
        ]),

# Animal Breed Filter using Dropdown
        html.Div(
            style={'display' : 'block', 'flex': '40%', 'border-left' : '4px solid black', 'border-right' : '4px solid black'},
            children=[
            html.Center(html.H2("Filter by Breed:")),
            dcc.Dropdown(
                options=breeds,
                value='No Filter',
                id="breed_filter",
                style={"width": "50%", 'min-width' : '50px', "height": "50px", 'margin' : 'auto'},
            ),      
        ]),

# Animal ID filter using search query
    #     html.Div(
    #         style={'display' : 'block', 'flex': '40%', 'border-right' : '4px solid black'},
    #         children=[
    #         html.Center(html.H2("Filter by Animal ID:")),
    #         html.Center(dcc.Input(id="search_field", type="text", placeholder="Search animals by animal ID:")),
    #     ]),
    ]),

    html.Hr(),

    dash_table.DataTable(
# necessary settings
        id="datatable-id",
        columns=[{"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns],
        data=df.to_dict("records"),

# interactivity to make data more manageable
        editable=True,
        filter_action="native",
        sort_action="native",
        sort_mode="multi",
        column_selectable="single",
        row_selectable="single",
        row_deletable=True,
        selected_columns=[],
        selected_rows=[0],
        page_action="native",
        page_current= 0,
        page_size= 10,
                        ),

    html.Hr(),
    html.Hr(),

# this formats the dashboard so that the chart and the geolocation chart are side-by-side
    html.Div(className="row",
         style={"display" : "flex"},
             children=[
        html.Div(
            id="graph-id",
            className="col s12 m6",

            ),
        html.Div(
            id="map-id",
            className="col s12 m6",
            )
        ])
])]

#############################################
# Interaction Between Components / Controller
#############################################

# redefine breed options based on inputs (animal ID and animal type), offer all but the currently selected breed if breed filter is set
@app.callback(
        Output("breed_filter", "options"),
        [Input("animal_filter", "value"),
        Input("breed_filter", "value"),]
)
def get_breed_options(animal_type, breed):
    # Dropdown is nullable
    if not breed:
        breed = "No Filter"

    # Implement No Filter as first option regardless, get all breeds
    breed_options = ["No Filter"]
    breeds = [breed for breed in df['breed'].unique()]

    # Breed filter is set, but not the animal type -> get animal_type implicitly and only list breeds of that type
    if breed != "No Filter" and animal_type == "No Filter":
        implicit_type = df.loc[df['breed'] == breed, 'animal_type'].values[0]
        if implicit_type == 'Cat':
            cats = df.loc[df['animal_type'] == 'Cat']
            breeds = cats['breed'].unique()
        elif implicit_type == 'Dog':
            dogs = df.loc[df['animal_type'] == 'Dog']
            breeds = dogs['breed'].unique()
        elif implicit_type == 'Other':
            other = df.loc[df['animal_type'] == 'Other']
            breeds = other['breed'].unique()


    # This is updated after the query updates data -> implicitly only accesses breeds of current animal type
    breeds.sort()
    breed_options.extend(breeds)


    
    return breed_options

@app.callback(
        Output("datatable-id", "data"),
        [Input("datatable-id", "data"),
         Input("animal_filter", "value"),
         Input("breed_filter", "value"),
        ]
)
def filter_query(data, animal_filter, breed_filter):
    # Refactor queries
    # query_parts = []
    # filter_queries = [{'animal_type': animal_filter}, {'breed' : breed_filter}, {'animal_id' : {"$regex": search_text, "$options" : "i"}}]

    # if search_text is None or not search_text.isalnum():
    #     search_text = ""
    # else:
    #      query_parts.append(filter_queries[2])

    # Dropdown is nullable
    if not breed_filter:
        breed_filter = "No Filter"
    # else:
    #     query_parts.append(filter_queries[1])

    if not animal_filter:
        animal_filter = "No Filter"
    # else:
    #      query_parts.append(filter_queries[0])

    # # if filter not empty -> add query to query_parts
    # # if len(query_parts) <= 1 -> single query
    # # else -> $and query
    # if len(query_parts) < 1:
    #     print("less than 1")
    # elif len(query_parts) == 1:
    #     print("equal to 1")
    # else:
    #     print("more than 1")

    # All filters set
    # if search_text != "" and animal_filter != 'No Filter' and breed_filter != 'No Filter':
    #     df = pd.DataFrame.from_records(db.read({
    #         '$and': [
    #             {'animal_type' : animal_filter},
    #             {'breed' : breed_filter},
    #             {'animal_id' : {"$regex": search_text, "$options" : "i"}}
    #         ]
    #     }))
    # Only Search and Animal Type filters set
    # elif search_text != "" and animal_filter != 'No Filter':
    #             df = pd.DataFrame.from_records(db.read({
    #         '$and': [
    #             {'animal_type' : animal_filter},
    #             {'animal_id' : {"$regex": search_text, "$options" : "i"}}
    #         ]
    #     }))
    # # Only Search and Breed filters set
    # elif search_text != "" and breed_filter != 'No Filter':
    #             df = pd.DataFrame.from_records(db.read({
    #         '$and': [
    #             {'breed' : breed_filter},
    #             {'animal_id' : {"$regex": search_text, "$options" : "i"}}
    #         ]
    #     }))
    # # Only Search filter set
    # elif search_text != "":
    #     df = pd.DataFrame.from_records(db.read({'animal_id' : {"$regex": search_text, "$options" : "i"}}))
    # # Only Animal Type and Breed filters set
    # elif animal_filter != 'No Filter' and breed_filter != 'No Filter':
    #     df = pd.DataFrame.from_records(db.read({
    #          '$and': [
    #                  {'animal_type' : animal_filter},
    #                  {'breed' : breed_filter},
    #             ]
    #     }))
    # Both filters set
    if animal_filter != "No Filter" and breed_filter != "No Filter":
        df = pd.DataFrame.from_records(db.read({
            "$and": [
                {'animal_type': animal_filter},
                {'breed': breed_filter}
            ]
        }))
    # Only Animal Type filter set
    elif animal_filter != 'No Filter':
        df = pd.DataFrame.from_records(db.read({'animal_type': animal_filter}))
    # Only Breed filter set
    elif breed_filter != 'No Filter':
        df = pd.DataFrame.from_records(db.read({ 'breed' : breed_filter}))
    # Potential uncaught path -> return all
    else:
        df = pd.DataFrame.from_records(db.read({}))

    if len(df) <= 0:
        print("No data found, returning full dataset")
        df = pd.DataFrame.from_records(db.read({}))

    # drop _id column and set datatable's new data
    if "_id" in df.columns:
        df.drop(columns=["_id"], inplace=True, errors="ignore")

    data = df.to_dict("records")
    
    return data

# Display the types of animal, further categorized by the secondary filter value given
@app.callback(
    Output("graph-id", "children"),
    Input("datatable-id", "derived_virtual_data"),
    [State("animal_filter", "value"),
     State("breed_filter", "value")]
)

def update_graphs(viewData, animal_filter, breed):
    # No data passed, return
    if viewData is None:
        return
    
    # Dropdown is nullable
    if not breed:
        breed= "No Filter"
            
    df = pd.DataFrame.from_dict(viewData)
         
    if animal_filter == "No Filter" and breed == "No Filter":
        fig = px.pie(values=df['animal_type'].value_counts(), names=df['animal_type'].unique(), title="Animals by Type")
    else:
        # If animal filter is set, categorize by breed instead, default anything less than 2% of the total into an 'others' slice
        small_slice_threshold = 0.02
        large_slice_labels = ['Other']
        large_slice_counts = [0]

        total_animals = df['breed'].count()

        for unique_breed in df['breed'].unique():
            type_count = df['breed'].value_counts()[unique_breed]

            if not type_count or type_count <= 0:
                continue
            elif  type_count / total_animals < small_slice_threshold:
                large_slice_counts[0] += type_count
            else:
                large_slice_labels.append(unique_breed)
                large_slice_counts.append(type_count)

        df = pd.DataFrame({"Labels": large_slice_labels, "Counts": large_slice_counts})
        fig = px.pie(values=large_slice_counts, names=large_slice_labels, title=f"Breeds of {animal_filter}")
    
    return dcc.Graph(figure=fig)

    
# # This callback will highlight a cell on the data table when the user selects it
@app.callback(
    Output("datatable-id", "style_data_conditional"),
    [Input("datatable-id", "selected_columns")]
)
def update_styles(selected_columns):
    return [{
        "if": { "column_id": i },
        "background_color": "#D2F3FF"
    } for i in selected_columns]


# # This callback will update the geo-location chart for the selected data entry
# # derived_virtual_data will be the set of data available from the datatable in the form of 
# # a dictionary.
# # derived_virtual_selected_rows will be the selected row(s) in the table in the form of
# # a list. For this application, we are only permitting single row selection so there is only
# # one value in the list.
# # The iloc method allows for a row, column notation to pull data from the datatable
@app.callback(
    Output("map-id", "children"),
    [Input("datatable-id", "derived_virtual_data"),
     Input("datatable-id", "derived_virtual_selected_rows")])
def update_map(viewData, index):  
    if viewData is None:
        return
    
    if index is None:
        return
    
    dff = pd.DataFrame.from_dict(viewData)
    # Because we only allow single row selection, the list can be converted to a row index here
    if index is None:
        row = 0
    else: 
        row = index[0]
        
    # Austin TX is at [30.75,-97.48]
    return [
        dl.Map(style={"width": "1000px", "height": "500px"}, center=[30.75,-97.48], zoom=10, children=[
            dl.TileLayer(id="base-layer-id"),
            # Marker with tool tip and popup
            # Column 13 and 14 define the grid-coordinates for the map
            # Column 4 defines the breed for the animal
            # Column 9 defines the name of the animal
            dl.Marker(position=[dff.iloc[row,13],dff.iloc[row,14]], children=[
                dl.Tooltip(dff.iloc[row,4]),
                dl.Popup([
                    html.H1("Animal Name"),
                    html.P(dff.iloc[row,9])
                ])
            ])
        ])
    ]


if __name__ == '__main__':
    app.run(mode="inline", debug=True, port=8050)
