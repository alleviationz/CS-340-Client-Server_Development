# %%
# Setup the Jupyter version of Dash
from jupyter_dash import JupyterDash

# Configure the necessary Python module imports for dashboard components
import dash_leaflet as dl
from dash import dcc
from dash import html
import plotly.express as px
from dash import dash_table
from dash.dependencies import Input, Output, State
import base64

# Configure OS routines
import os

# Configure the plotting routines
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import Project_One as AAC

###########################
# Data Manipulation / Model
###########################

# hard-wired database user and pass
username = "aacuser"
password = "SNHU1234"

# Connect to database via CRUD Module
db = AAC.AnimalShelter(username, password)

# class read method must support return of list object and accept projection json input
# sending the read method an empty document requests all documents be returned
df = pd.DataFrame.from_records(db.read({}))

# MongoDB v5+ is going to return the '_id' column and that is going to have an 
# invlaid object type of 'ObjectID' - which will cause the data_table to crash - so we remove
# it in the dataframe here. The df.drop command allows us to drop the column. If we do not set
# inplace=True - it will reeturn a new dataframe that does not contain the dropped column(s)
df.drop(columns=['_id'],inplace=True)

## Debug
# print(len(df.to_dict(orient='records')))
# print(df.columns)


#########################
# Dashboard Layout / View
#########################
app = JupyterDash(__name__)

# logo img path
image_filename = './Grazioso_Salvare_Logo.png'
encoded_image = base64.b64encode(open(image_filename, 'rb').read())


app.layout = html.Div([
    dcc.Link(
        html.Img(src='data:image/png;base64,{}'.format(encoded_image.decode()),
                 alt='Grazioso Logo', height="200", width="200"),
                href="snhu.edu"),
#    html.Div(id='hidden-div', style={'display':'none'}),
    html.Center(html.B(html.H1('CS-340 Dashboard'))),
    html.H1("Alec Novak - SNHU"),
    html.Hr(),
# radio items that pass filter value to callback
    dcc.RadioItems(
        id="animal_filter",
        options=[{'label': i, 'value': i} for i in ["All Animals", "Water", "Wilderness/Mountains", "Disaster/Tracking"]],
value="All Animals"),
    html.Hr(),
    dash_table.DataTable(id='datatable-id',
    columns=[{"name": i, "id": i, "deletable": False, "selectable": True} for i in df.columns],
# interactivity to make data more manageable
        data=df.to_dict('records'),
        editable=True,
        filter_action="native",
        sort_action="native",
        sort_mode="multi",
        column_selectable="single",
        row_selectable="single",
        row_deletable=True,
        selected_columns=[],
        selected_rows=[0],
        page_action="native",
        page_current= 0,
        page_size= 10,
                        ),
    html.Br(),
    html.Hr(),
#This sets up the dashboard so that your chart and your geolocation chart are side-by-side
    html.Div(className='row',
         style={'display' : 'flex'},
             children=[
        html.Div(
            id='graph-id',
            className='col s12 m6',

            ),
        html.Div(
            id='map-id',
            className='col s12 m6',
            )
        ])
])

#############################################
# Interaction Between Components / Controller
#############################################



    
# filtering callback
@app.callback(
    Output('datatable-id', 'data'),
    Input('animal_filter', 'value')
)

def animal_filter(filter):
    # load data
    df = pd.DataFrame.from_records(db.read({}))
    
    # query data dependent on filter
    #reset filter
    if (filter == "All Animals"):
        df = pd.DataFrame.from_records(db.read({}))
        
    # filter animals that meet requirements for water rescue
    elif (filter == 'Water'):
        df = pd.DataFrame.from_records(db.read({"breed" : {
            "$in":
                ["Labrador Retriever Mix", "Chesapeake Bay Retriever", "Newfoundland"]},
                'sex_upon_outcome': 'Intact Female',
                'age_upon_outcome_in_weeks': {'$gte': 26},
                'age_upon_outcome_in_weeks': {'$lte': 156}}))
        
    # filter animals that meet requirements for wilderness and mountain rescue 
    elif (filter == 'Wilderness/Mountains'):
        df = pd.DataFrame.from_records(db.read({"breed" : {
            "$in":
                ["German Shepherd", "Alaskan Malamute", "Old English Sheepdog", "Siberian Husky", "Rottweiler"]},
                'sex_upon_outcome': 'Intact Male',
                'age_upon_outcome_in_weeks': {'$gte': 26},
                'age_upon_outcome_in_weeks': {'$lte': 156}}))
        
    #filter animals that meet requirements for disaster and tracking rescue
    elif (filter == 'Disaster/Tracking'):
        df = pd.DataFrame.from_records(db.read({"breed" : {
            "$in":
                ["Doberman Pinscher", "Alaskan Malamute", "German Shepherd", "Golden Retriever", "Bloodhound", "Rottweiler"]},
                'sex_upon_outcome': 'Intact Male',
                'age_upon_outcome_in_weeks': {'$gte': 20},
                'age_upon_outcome_in_weeks': {'$lte': 300}}))
        
    # if a different value than expected, reset filter
    else:
        df = pd.DataFrame.from_records(db.read({}))
        
    # drop _id column
    df.drop(columns=['_id'],inplace=True)
    data = df.to_dict('records')
    
    return (data)

# Display the breeds of animal based on quantity represented in
# the data table, connected to filter
@app.callback(
    Output('graph-id', "children"),
    [Input('datatable-id', 'derived_viewport_data'),
    Input('animal_filter', 'value')])
def update_graphs(viewData, filter):
    
    df = pd.DataFrame.from_dict(viewData)
    
    # query data dependent on filter
    # reset filter when "All Animals" is passed
    if (filter == "All Animals"):
        df = pd.DataFrame.from_records(db.read({}))
    
    # configure the graph with the resulting dataframe
    return [
        dcc.Graph(            
            figure = px.pie(df, names='breed', title='Preferred Animals')
        )    
    ]
    
#This callback will highlight a cell on the data table when the user selects it
@app.callback(
    Output('datatable-id', 'style_data_conditional'),
    [Input('datatable-id', 'selected_columns')]
)
def update_styles(selected_columns):
    return [{
        'if': { 'column_id': i },
        'background_color': '#D2F3FF'
    } for i in selected_columns]


# This callback will update the geo-location chart for the selected data entry
# derived_virtual_data will be the set of data available from the datatable in the form of 
# a dictionary.
# derived_virtual_selected_rows will be the selected row(s) in the table in the form of
# a list. For this application, we are only permitting single row selection so there is only
# one value in the list.
# The iloc method allows for a row, column notation to pull data from the datatable
@app.callback(
    Output('map-id', "children"),
    [Input('datatable-id', "derived_virtual_data"),
     Input('datatable-id', "derived_virtual_selected_rows")])
def update_map(viewData, index):  
    if viewData is None:
        return
    elif index is None:
        return
    
    dff = pd.DataFrame.from_dict(viewData)
    # Because we only allow single row selection, the list can be converted to a row index here
    if index is None:
        row = 0
    else: 
        row = index[0]
        
    # Austin TX is at [30.75,-97.48]
    return [
        dl.Map(style={'width': '1000px', 'height': '500px'}, center=[30.75,-97.48], zoom=10, children=[
            dl.TileLayer(id="base-layer-id"),
            # Marker with tool tip and popup
            # Column 13 and 14 define the grid-coordinates for the map
            # Column 4 defines the breed for the animal
            # Column 9 defines the name of the animal
            dl.Marker(position=[dff.iloc[row,13],dff.iloc[row,14]], children=[
                dl.Tooltip(dff.iloc[row,4]),
                dl.Popup([
                    html.H1("Animal Name"),
                    html.P(dff.iloc[row,9])
                ])
            ])
        ])
    ]



app.run_server(debug=True)
# Out:
# {'_id': ObjectId('679fb19627a977cd0fdcb975'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('679fb1a90ac3e65c163ae588'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a253b3e16796240535e73c'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a25450e16796240535e73e'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a254ace16796240535e740'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a25641c0bc52e6de0d154e'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a25656c0bc52e6de0d1550'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a256a8c0bc52e6de0d1552'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a256e6c0bc52e6de0d1554'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a2587dc0bc52e6de0d1556'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a2588dc0bc52e6de0d1558'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a25b6fc0bc52e6de0d155a'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a279051104338c27cc4948'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a2798f1104338c27cc494a'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a279f11104338c27cc494c'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a27b3409553cecbe235193'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a27c2509553cecbe235195'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a27d3a09553cecbe235198'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a27daf09553cecbe23519a'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a27dc909553cecbe23519c'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a2800cc43ebb0a4458a1e1'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a2802430be13c986e2b546'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a281a4d2c22ee2e4ec4d7d'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a2829993b5ae58967ddb02'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a283e4e480d4c0b9c2a797'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a283fdd80423a33c755a40'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a284cd3e6b447bde28f999'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a2859752f2dc82599ad54e'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a395e2661e44ea29e3f057'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a3971fabf205e83a3656ef'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a3974a5d9b750357cb3e2d'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a3979defa84ce42d1a37f2'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a398676635e662ef9cf430'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a39b804f15b936677a90a8'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a39bf079db091bb124930b'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67a39e57545d6e9c8d8e1616'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'B746874',
#  'animal_type': 'Dog',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b22e41b2e0b1db0e61da13'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 148.767857142857,
#  'animal_id': 'A746874',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 28.5066578739455,
#  'location_long': -47.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b22e52569eed6cbe5a56a8'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 148.767857142857,
#  'animal_id': 'A746874',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 28.5066578739455,
#  'location_long': -47.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': '1',
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bc9'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.9215277777778,
#  'animal_id': 'A725717',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Silver Tabby',
#  'date_of_birth': '2015-05-02',
#  'datetime': '2016-05-06 10:49:00',
#  'location_lat': 30.6525984560228,
#  'location_long': -97.7419963476444,
#  'monthyear': '2016-05-06T10:49:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': 2,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bca'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 110.111408730159,
#  'animal_id': 'A716330',
#  'animal_type': 'Dog',
#  'breed': 'Chihuahua Shorthair Mix',
#  'color': 'Brown/White',
#  'date_of_birth': '2013-11-18',
#  'datetime': '2015-12-28 18:43:00',
#  'location_lat': 30.7595748121648,
#  'location_long': -97.5523753807133,
#  'monthyear': '2015-12-28T18:43:00',
#  'name': 'Frank',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 3,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bcb'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 58.9642857142857,
#  'animal_id': 'A736551',
#  'animal_type': 'Dog',
#  'breed': 'Labrador Retriever/Australian Cattle Dog',
#  'color': 'Black',
#  'date_of_birth': '2015-10-12',
#  'datetime': '2016-11-27 18:00:00',
#  'location_lat': 30.4443212820182,
#  'location_long': -97.7326980338793,
#  'monthyear': '2016-11-27T18:00:00',
#  'name': '*Mia',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 8,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bcc'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 62.2464285714286,
#  'animal_id': 'A664843',
#  'animal_type': 'Dog',
#  'breed': 'Pit Bull Mix',
#  'color': 'Brown/White',
#  'date_of_birth': '2013-06-09',
#  'datetime': '2014-08-18 17:24:00',
#  'location_lat': 30.4515549397366,
#  'location_long': -97.474104510925,
#  'monthyear': '2014-08-18T17:24:00',
#  'name': 'Sherlock',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 12,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bcd'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.767857142857,
#  'animal_id': 'A746874',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2014-04-10',
#  'datetime': '2017-04-11 09:00:00',
#  'location_lat': 30.5066578739455,
#  'location_long': -97.3408780722188,
#  'monthyear': '2017-04-11T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': 1,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bce'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.9215277777778,
#  'animal_id': 'A725717',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Silver Tabby',
#  'date_of_birth': '2015-05-02',
#  'datetime': '2016-05-06 10:49:00',
#  'location_lat': 30.6525984560228,
#  'location_long': -97.7419963476444,
#  'monthyear': '2016-05-06T10:49:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': 2,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bcf'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 110.111408730159,
#  'animal_id': 'A716330',
#  'animal_type': 'Dog',
#  'breed': 'Chihuahua Shorthair Mix',
#  'color': 'Brown/White',
#  'date_of_birth': '2013-11-18',
#  'datetime': '2015-12-28 18:43:00',
#  'location_lat': 30.7595748121648,
#  'location_long': -97.5523753807133,
#  'monthyear': '2015-12-28T18:43:00',
#  'name': 'Frank',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 3,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bd0'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 58.9642857142857,
#  'animal_id': 'A736551',
#  'animal_type': 'Dog',
#  'breed': 'Labrador Retriever/Australian Cattle Dog',
#  'color': 'Black',
#  'date_of_birth': '2015-10-12',
#  'datetime': '2016-11-27 18:00:00',
#  'location_lat': 30.4443212820182,
#  'location_long': -97.7326980338793,
#  'monthyear': '2016-11-27T18:00:00',
#  'name': '*Mia',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 8,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bd1'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 62.2464285714286,
#  'animal_id': 'A664843',
#  'animal_type': 'Dog',
#  'breed': 'Pit Bull Mix',
#  'color': 'Brown/White',
#  'date_of_birth': '2013-06-09',
#  'datetime': '2014-08-18 17:24:00',
#  'location_lat': 30.4515549397366,
#  'location_long': -97.474104510925,
#  'monthyear': '2014-08-18T17:24:00',
#  'name': 'Sherlock',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 12,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bd2'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.5093253968254,
#  'animal_id': 'A700408',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Brown Tabby/White',
#  'date_of_birth': '2014-04-13',
#  'datetime': '2015-04-15 13:34:00',
#  'location_lat': 30.4101154527976,
#  'location_long': -97.562415670838,
#  'monthyear': '2015-04-15T13:34:00',
#  'name': 'Nyla',
#  'outcome_subtype': '',
#  'outcome_type': 'Return to Owner',
#  'rec_num': 13,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bd3'),
#  'age_upon_outcome': '7 months',
#  'age_upon_outcome_in_weeks': 30.8225198412698,
#  'animal_id': 'A733653',
#  'animal_type': 'Cat',
#  'breed': 'Siamese Mix',
#  'color': 'Seal Point',
#  'date_of_birth': '2016-01-25',
#  'datetime': '2016-08-27 18:11:00',
#  'location_lat': 30.3188063374257,
#  'location_long': -97.7240376703891,
#  'monthyear': '2016-08-27T18:11:00',
#  'name': 'Kitty',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 4,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67b762048c9814ab03039bd4'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 107.931547619048,
#  'animal_id': 'A742287',
#  'animal_type': 'Dog',
#  'breed': 'Boxer/Bullmastiff',
#  'color': 'Brown Brindle/White',
#  'date_of_birth': '2015-01-18',
#  'datetime': '2017-02-11 12:30:00',
#  'location_lat': 30.4551148649096,
#  'location_long': -97.3087780473978,
#  'monthyear': '2017-02-11T12:30:00',
#  'name': '*Kawhi',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 14,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bd5'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 198.820634920635,
#  'animal_id': 'A712638',
#  'animal_type': 'Dog',
#  'breed': 'Pit Bull Mix',
#  'color': 'Red/White',
#  'date_of_birth': '2012-09-26',
#  'datetime': '2016-07-18 17:52:00',
#  'location_lat': 30.5798299207017,
#  'location_long': -97.5588487936533,
#  'monthyear': '2016-07-18T17:52:00',
#  'name': 'Marcus',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 15,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bd6'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 106.662202380952,
#  'animal_id': 'A673830',
#  'animal_type': 'Dog',
#  'breed': 'Pit Bull Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2012-03-03',
#  'datetime': '2014-03-19 15:15:00',
#  'location_lat': 30.2954256583441,
#  'location_long': -97.3136642110436,
#  'monthyear': '2014-03-19T15:15:00',
#  'name': '*Seth',
#  'outcome_subtype': 'Aggressive',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 7,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bd7'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 133.653571428571,
#  'animal_id': 'A691584',
#  'animal_type': 'Dog',
#  'breed': 'Labrador Retriever Mix',
#  'color': 'Tan/White',
#  'date_of_birth': '2012-11-06',
#  'datetime': '2015-05-30 13:48:00',
#  'location_lat': 30.7104815618433,
#  'location_long': -97.562297435286,
#  'monthyear': '2015-05-30T13:48:00',
#  'name': 'Luke',
#  'outcome_subtype': '',
#  'outcome_type': 'Return to Owner',
#  'rec_num': 5,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bd8'),
#  'age_upon_outcome': '3 months',
#  'age_upon_outcome_in_weeks': 14.0890873015873,
#  'animal_id': 'A664290',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Tortie',
#  'date_of_birth': '2013-09-01',
#  'datetime': '2013-12-08 14:58:00',
#  'location_lat': 30.7583105481048,
#  'location_long': -97.618292198845,
#  'monthyear': '2013-12-08T14:58:00',
#  'name': '*Taylor',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 10,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bd9'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 157.504067460317,
#  'animal_id': 'A720214',
#  'animal_type': 'Dog',
#  'breed': 'Labrador Retriever Mix',
#  'color': 'Red/White',
#  'date_of_birth': '2013-02-04',
#  'datetime': '2016-02-11 12:41:00',
#  'location_lat': 30.3870648199411,
#  'location_long': -97.3684339731375,
#  'monthyear': '2016-02-11T12:41:00',
#  'name': 'Blessing',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 9,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bda'),
#  'age_upon_outcome': '5 years',
#  'age_upon_outcome_in_weeks': 261.818154761905,
#  'animal_id': 'A723742',
#  'animal_type': 'Dog',
#  'breed': 'Miniature Schnauzer Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2011-04-05',
#  'datetime': '2016-04-10 17:27:00',
#  'location_lat': 30.4792884863566,
#  'location_long': -97.4088531587999,
#  'monthyear': '2016-04-10T17:27:00',
#  'name': 'Gretchen',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 16,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bdb'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.8203373015873,
#  'animal_id': 'A721199',
#  'animal_type': 'Dog',
#  'breed': 'Dachshund Wirehair Mix',
#  'color': 'Tan/White',
#  'date_of_birth': '2015-02-23',
#  'datetime': '2016-02-27 17:49:00',
#  'location_lat': 30.7290272761146,
#  'location_long': -97.3753328216134,
#  'monthyear': '2016-02-27T17:49:00',
#  'name': 'Belle',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 11,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bdc'),
#  'age_upon_outcome': '6 months',
#  'age_upon_outcome_in_weeks': 28.3865079365079,
#  'animal_id': 'A668960',
#  'animal_type': 'Dog',
#  'breed': 'Pit Bull Mix',
#  'color': 'Blue/White',
#  'date_of_birth': '2013-06-12',
#  'datetime': '2013-12-27 16:56:00',
#  'location_lat': 30.5943410758588,
#  'location_long': -97.2489933569515,
#  'monthyear': '2013-12-27T16:56:00',
#  'name': '*Gigi',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 17,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bdd'),
#  'age_upon_outcome': '5 years',
#  'age_upon_outcome_in_weeks': 261.063392857143,
#  'animal_id': 'A696004',
#  'animal_type': 'Dog',
#  'breed': 'Cardigan Welsh Corgi Mix',
#  'color': 'Sable/White',
#  'date_of_birth': '2010-01-27',
#  'datetime': '2015-01-28 10:39:00',
#  'location_lat': 30.6737365854231,
#  'location_long': -97.707971529467,
#  'monthyear': '2015-01-28T10:39:00',
#  'name': 'Lucy',
#  'outcome_subtype': 'Rabies Risk',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 6,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bde'),
#  'age_upon_outcome': '5 years',
#  'age_upon_outcome_in_weeks': 306.537003968254,
#  'animal_id': 'A615748',
#  'animal_type': 'Dog',
#  'breed': 'Labrador Retriever Mix',
#  'color': 'Black',
#  'date_of_birth': '2009-12-11',
#  'datetime': '2015-10-26 18:13:00',
#  'location_lat': 30.7172069757685,
#  'location_long': -97.2952833147647,
#  'monthyear': '2015-10-26T18:13:00',
#  'name': 'Blackie',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 22,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bdf'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.4821428571429,
#  'animal_id': 'A743231',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Black',
#  'date_of_birth': '2016-02-06',
#  'datetime': '2017-02-07 09:00:00',
#  'location_lat': 30.2920163966506,
#  'location_long': -97.4266291874198,
#  'monthyear': '2017-02-07T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': 26,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67b762048c9814ab03039be0'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.642658730159,
#  'animal_id': 'A764418',
#  'animal_type': 'Dog',
#  'breed': 'Chihuahua Shorthair Mix',
#  'color': 'Tan/White',
#  'date_of_birth': '2015-12-29',
#  'datetime': '2017-12-30 11:58:00',
#  'location_lat': 30.277168944418,
#  'location_long': -97.7122755507492,
#  'monthyear': '2017-12-30T11:58:00',
#  'name': 'Burro',
#  'outcome_subtype': '',
#  'outcome_type': 'Return to Owner',
#  'rec_num': 27,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039be1'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 69.2319444444445,
#  'animal_id': 'A743879',
#  'animal_type': 'Dog',
#  'breed': 'Pit Bull Mix',
#  'color': 'Black/White',
#  'date_of_birth': '2016-02-18',
#  'datetime': '2017-06-16 14:58:00',
#  'location_lat': 30.757367526077,
#  'location_long': -97.4667421648321,
#  'monthyear': '2017-06-16T14:58:00',
#  'name': '*Tallulah',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 28,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039be2'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 9.14285714285714,
#  'animal_id': 'A756064',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Blue',
#  'date_of_birth': '2017-06-13',
#  'datetime': '2017-08-16 00:00:00',
#  'location_lat': 30.2934116611166,
#  'location_long': -97.2901948420822,
#  'monthyear': '2017-08-16T00:00:00',
#  'name': '',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 29,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67b762048c9814ab03039be3'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 191.255753968254,
#  'animal_id': 'A648094',
#  'animal_type': 'Dog',
#  'breed': 'Dachshund/Chihuahua Shorthair',
#  'color': 'Red',
#  'date_of_birth': '2012-11-21',
#  'datetime': '2016-07-21 18:58:00',
#  'location_lat': 30.7173271019582,
#  'location_long': -97.4883408278017,
#  'monthyear': '2016-07-21T18:58:00',
#  'name': 'Brawndo',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 30,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039be4'),
#  'age_upon_outcome': '5 years',
#  'age_upon_outcome_in_weeks': 282.67371031746,
#  'animal_id': 'A651202',
#  'animal_type': 'Dog',
#  'breed': 'Maltese Mix',
#  'color': 'White',
#  'date_of_birth': '2009-04-07',
#  'datetime': '2014-09-06 17:11:00',
#  'location_lat': 30.4874006446211,
#  'location_long': -97.7300741137765,
#  'monthyear': '2014-09-06T17:11:00',
#  'name': 'Daisy',
#  'outcome_subtype': '',
#  'outcome_type': 'Return to Owner',
#  'rec_num': 31,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039be5'),
#  'age_upon_outcome': '3 months',
#  'age_upon_outcome_in_weeks': 14.5386904761905,
#  'animal_id': 'A687515',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Orange Tabby',
#  'date_of_birth': '2014-05-29',
#  'datetime': '2014-09-07 18:30:00',
#  'location_lat': 30.5370536731062,
#  'location_long': -97.5684815578894,
#  'monthyear': '2014-09-07T18:30:00',
#  'name': 'Dinah',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 32,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039be6'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 105.543948412698,
#  'animal_id': 'A709958',
#  'animal_type': 'Dog',
#  'breed': 'Australian Cattle Dog Mix',
#  'color': 'Brown Brindle/White',
#  'date_of_birth': '2013-08-15',
#  'datetime': '2015-08-23 19:23:00',
#  'location_lat': 30.6937385067567,
#  'location_long': -97.5766003196181,
#  'monthyear': '2015-08-23T19:23:00',
#  'name': 'Jack',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 33,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67b762048c9814ab03039be7'),
#  'age_upon_outcome': '4 months',
#  'age_upon_outcome_in_weeks': 18.0833333333333,
#  'animal_id': 'A709511',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Medium Hair Mix',
#  'color': 'White/Black',
#  'date_of_birth': '2015-07-10',
#  'datetime': '2015-11-13 14:00:00',
#  'location_lat': 30.5202877527245,
#  'location_long': -97.6574204375118,
#  'monthyear': '2015-11-13T14:00:00',
#  'name': '*Toad',
#  'outcome_subtype': 'Foster',
#  'outcome_type': 'Adoption',
#  'rec_num': 19,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039be8'),
#  'age_upon_outcome': '3 months',
#  'age_upon_outcome_in_weeks': 13.5435515873016,
#  'animal_id': 'A753983',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Orange Tabby',
#  'date_of_birth': '2017-04-13',
#  'datetime': '2017-07-16 19:19:00',
#  'location_lat': 30.4301887696662,
#  'location_long': -97.5837553641966,
#  'monthyear': '2017-07-16T19:19:00',
#  'name': '',
#  'outcome_subtype': 'Snr',
#  'outcome_type': 'Transfer',
#  'rec_num': 34,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b762048c9814ab03039be9'),
#  'age_upon_outcome': '7 years',
#  'age_upon_outcome_in_weeks': 365.339285714286,
#  'animal_id': 'A712377',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Brown Tabby/White',
#  'date_of_birth': '2008-09-22',
#  'datetime': '2015-09-23 09:00:00',
#  'location_lat': 30.5914919451752,
#  'location_long': -97.6417061435299,
#  'monthyear': '2015-09-23T09:00:00',
#  'name': '',
#  'outcome_subtype': 'SCRP',
#  'outcome_type': 'Transfer',
#  'rec_num': 35,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039bea'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 64.8196428571429,
#  'animal_id': 'A693126',
#  'animal_type': 'Dog',
#  'breed': 'American Bulldog Mix',
#  'color': 'White/Brown',
#  'date_of_birth': '2013-12-02',
#  'datetime': '2015-02-28 17:42:00',
#  'location_lat': 30.577712300078,
#  'location_long': -97.6438826598467,
#  'monthyear': '2015-02-28T17:42:00',
#  'name': 'George',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 20,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b762048c9814ab03039beb'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.3964285714286,
#  'animal_id': 'A693288',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Brown Tabby/White',
#  'date_of_birth': '2014-09-28',
#  'datetime': '2014-12-09 18:36:00',
#  'location_lat': 30.4527678292931,
#  'location_long': -97.4620507167676,
#  'monthyear': '2014-12-09T18:36:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 18,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bec'),
#  'age_upon_outcome': '3 weeks',
#  'age_upon_outcome_in_weeks': 3.2405753968254,
#  'animal_id': 'A704707',
#  'animal_type': 'Cat',
#  'breed': 'Siamese Mix',
#  'color': 'Seal Point',
#  'date_of_birth': '2015-05-17',
#  'datetime': '2015-06-08 16:25:00',
#  'location_lat': 30.7099356408815,
#  'location_long': -97.6968533378074,
#  'monthyear': '2015-06-08T16:25:00',
#  'name': '',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 24,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b762048c9814ab03039bed'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Pit Bull Mix',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Mia',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bee'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 9.35128968253968,
#  'animal_id': 'A725966',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Tortie',
#  'date_of_birth': '2016-03-20',
#  'datetime': '2016-05-24 11:01:00',
#  'location_lat': 30.5201707620679,
#  'location_long': -97.5317824337026,
#  'monthyear': '2016-05-24T11:01:00',
#  'name': '*Star',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 25,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bef'),
#  'age_upon_outcome': '6 months',
#  'age_upon_outcome_in_weeks': 30.3544642857143,
#  'animal_id': 'A706953',
#  'animal_type': 'Dog',
#  'breed': 'Labrador Retriever Mix',
#  'color': 'Yellow',
#  'date_of_birth': '2014-12-06',
#  'datetime': '2015-07-06 11:33:00',
#  'location_lat': 30.5480802368633,
#  'location_long': -97.2969969058957,
#  'monthyear': '2015-07-06T11:33:00',
#  'name': '',
#  'outcome_subtype': 'Medical',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 36,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67b762048c9814ab03039bf0'),
#  'age_upon_outcome': '3 months',
#  'age_upon_outcome_in_weeks': 13.9688492063492,
#  'animal_id': 'A739519',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'Brown Tabby',
#  'date_of_birth': '2016-11-06',
#  'datetime': '2017-02-11 18:46:00',
#  'location_lat': 30.6831812834341,
#  'location_long': -97.2458191635746,
#  'monthyear': '2017-02-11T18:46:00',
#  'name': 'Mojito',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 37,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b762048c9814ab03039bf1'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 11.4285714285714,
#  'animal_id': 'A760125',
#  'animal_type': 'Cat',
#  'breed': 'Domestic Shorthair Mix',
#  'color': 'White/Black',
#  'date_of_birth': '2017-07-29',
#  'datetime': '2017-10-17 00:00:00',
#  'location_lat': 30.5414256979756,
#  'location_long': -97.4633994244696,
#  'monthyear': '2017-10-17T00:00:00',
#  'name': '',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 38,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad04c'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.2470238095238,
#  'animal_id': 'A675124',
#  'animal_type': 'Dog',
#  'breed': 'Bloodhound',
#  'color': 'Black/Brown',
#  'date_of_birth': '2013-03-23',
#  'datetime': '2014-03-23 17:30:00',
#  'location_lat': 30.397292292142,
#  'location_long': -97.305300387329,
#  'monthyear': '2014-03-23T17:30:00',
#  'name': '',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 334,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad04d'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.820833333333,
#  'animal_id': 'A678393',
#  'animal_type': 'Dog',
#  'breed': 'Golden Retriever',
#  'color': 'Brown',
#  'date_of_birth': '2011-05-08',
#  'datetime': '2014-05-09 17:54:00',
#  'location_lat': 30.429299327634,
#  'location_long': -97.6161732279484,
#  'monthyear': '2014-05-09T17:54:00',
#  'name': 'Bebe',
#  'outcome_subtype': '',
#  'outcome_type': 'Return to Owner',
#  'rec_num': 315,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad04e'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 12.959623015873,
#  'animal_id': 'A746862',
#  'animal_type': 'Dog',
#  'breed': 'Doberman Pinscher',
#  'color': 'Black/Brown',
#  'date_of_birth': '2017-01-14',
#  'datetime': '2017-04-14 17:13:00',
#  'location_lat': 30.4105077089376,
#  'location_long': -97.6502521344198,
#  'monthyear': '2017-04-14T17:13:00',
#  'name': 'Harley',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 335,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad04f'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 11.212003968254,
#  'animal_id': 'A758584',
#  'animal_type': 'Dog',
#  'breed': 'Siberian Husky',
#  'color': 'White/Black',
#  'date_of_birth': '2017-09-09',
#  'datetime': '2017-11-26 11:37:00',
#  'location_lat': 30.3491408570609,
#  'location_long': -97.4793291291553,
#  'monthyear': '2017-11-26T11:37:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 336,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad050'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.478075396825,
#  'animal_id': 'A693651',
#  'animal_type': 'Dog',
#  'breed': 'Old English Sheepdog',
#  'color': 'Brown',
#  'date_of_birth': '2012-12-12',
#  'datetime': '2014-12-13 08:19:00',
#  'location_lat': 30.2891932621479,
#  'location_long': -97.5459715509776,
#  'monthyear': '2014-12-13T08:19:00',
#  'name': '',
#  'outcome_subtype': 'Rabies Risk',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 337,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad051'),
#  'age_upon_outcome': '8 years',
#  'age_upon_outcome_in_weeks': 418.051388888889,
#  'animal_id': 'A747978',
#  'animal_type': 'Dog',
#  'breed': 'Newfoundland',
#  'color': 'Red',
#  'date_of_birth': '2009-04-27',
#  'datetime': '2017-05-01 08:38:00',
#  'location_lat': 30.4719392379806,
#  'location_long': -97.4471394988203,
#  'monthyear': '2017-05-01T08:38:00',
#  'name': '',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 341,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad052'),
#  'age_upon_outcome': '4 years',
#  'age_upon_outcome_in_weeks': 208.658630952381,
#  'animal_id': 'A616906',
#  'animal_type': 'Dog',
#  'breed': 'German Shepherd',
#  'color': 'Brown/Black',
#  'date_of_birth': '2010-07-01',
#  'datetime': '2014-06-30 14:39:00',
#  'location_lat': 30.2731134919741,
#  'location_long': -97.321918009823,
#  'monthyear': '2014-06-30T14:39:00',
#  'name': 'Estrella',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 346,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad053'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.9364087301587,
#  'animal_id': 'A705590',
#  'animal_type': 'Dog',
#  'breed': 'Chesapeake Bay Retriever',
#  'color': 'Black Brindle',
#  'date_of_birth': '2015-04-12',
#  'datetime': '2015-06-27 13:19:00',
#  'location_lat': 30.7083179097166,
#  'location_long': -97.3924668221853,
#  'monthyear': '2015-06-27T13:19:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 347,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b76c17bb1e4e8855dad054'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.9364087301587,
#  'animal_id': 'A705590',
#  'animal_type': 'Dog',
#  'breed': 'Rottweiler',
#  'color': 'Black/Brown',
#  'date_of_birth': '2015-04-12',
#  'datetime': '2015-06-27 13:19:00',
#  'location_lat': 30.7083179097166,
#  'location_long': -97.3924668221853,
#  'monthyear': '2015-06-27T13:19:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 357,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b76d2068afd1dc0531a134'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.2470238095238,
#  'animal_id': 'A675124',
#  'animal_type': 'Dog',
#  'breed': 'Bloodhound',
#  'color': 'Black/Brown',
#  'date_of_birth': '2013-03-23',
#  'datetime': '2014-03-23 17:30:00',
#  'location_lat': 30.397292292142,
#  'location_long': -97.305300387329,
#  'monthyear': '2014-03-23T17:30:00',
#  'name': '',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 334,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b76d2068afd1dc0531a135'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.820833333333,
#  'animal_id': 'A678393',
#  'animal_type': 'Dog',
#  'breed': 'Golden Retriever',
#  'color': 'Brown',
#  'date_of_birth': '2011-05-08',
#  'datetime': '2014-05-09 17:54:00',
# ...
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 347,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b76d2068afd1dc0531a13c'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.9364087301587,
#  'animal_id': 'A705590',
#  'animal_type': 'Dog',
#  'breed': 'Rottweiler',
#  'color': 'Black/Brown',
#  'date_of_birth': '2015-04-12',
#  'datetime': '2015-06-27 13:19:00',
#  'location_lat': 30.7083179097166,
#  'location_long': -97.3924668221853,
#  'monthyear': '2015-06-27T13:19:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 357,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b9f4175a0637a05acbec12'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.2470238095238,
#  'animal_id': 'A675124',
#  'animal_type': 'Dog',
#  'breed': 'Bloodhound',
#  'color': 'Black/Brown',
#  'date_of_birth': '2013-03-23',
#  'datetime': '2014-03-23 17:30:00',
#  'location_lat': 30.397292292142,
#  'location_long': -97.305300387329,
#  'monthyear': '2014-03-23T17:30:00',
#  'name': '',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 334,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b9f4175a0637a05acbec13'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.820833333333,
#  'animal_id': 'A678393',
#  'animal_type': 'Dog',
#  'breed': 'Golden Retriever',
#  'color': 'Brown',
#  'date_of_birth': '2011-05-08',
#  'datetime': '2014-05-09 17:54:00',
#  'location_lat': 30.429299327634,
#  'location_long': -97.6161732279484,
#  'monthyear': '2014-05-09T17:54:00',
#  'name': 'Bebe',
#  'outcome_subtype': '',
#  'outcome_type': 'Return to Owner',
#  'rec_num': 315,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b9f4175a0637a05acbec14'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 12.959623015873,
#  'animal_id': 'A746862',
#  'animal_type': 'Dog',
#  'breed': 'Doberman Pinscher',
#  'color': 'Black/Brown',
#  'date_of_birth': '2017-01-14',
#  'datetime': '2017-04-14 17:13:00',
#  'location_lat': 30.4105077089376,
#  'location_long': -97.6502521344198,
#  'monthyear': '2017-04-14T17:13:00',
#  'name': 'Harley',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 335,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b9f4175a0637a05acbec15'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 11.212003968254,
#  'animal_id': 'A758584',
#  'animal_type': 'Dog',
#  'breed': 'Siberian Husky',
#  'color': 'White/Black',
#  'date_of_birth': '2017-09-09',
#  'datetime': '2017-11-26 11:37:00',
#  'location_lat': 30.3491408570609,
#  'location_long': -97.4793291291553,
#  'monthyear': '2017-11-26T11:37:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 336,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b9f4175a0637a05acbec16'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.478075396825,
#  'animal_id': 'A693651',
#  'animal_type': 'Dog',
#  'breed': 'Old English Sheepdog',
#  'color': 'Brown',
#  'date_of_birth': '2012-12-12',
#  'datetime': '2014-12-13 08:19:00',
#  'location_lat': 30.2891932621479,
#  'location_long': -97.5459715509776,
#  'monthyear': '2014-12-13T08:19:00',
#  'name': '',
#  'outcome_subtype': 'Rabies Risk',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 337,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b9f4175a0637a05acbec17'),
#  'age_upon_outcome': '8 years',
#  'age_upon_outcome_in_weeks': 418.051388888889,
#  'animal_id': 'A747978',
#  'animal_type': 'Dog',
#  'breed': 'Newfoundland',
#  'color': 'Red',
#  'date_of_birth': '2009-04-27',
#  'datetime': '2017-05-01 08:38:00',
#  'location_lat': 30.4719392379806,
#  'location_long': -97.4471394988203,
#  'monthyear': '2017-05-01T08:38:00',
#  'name': '',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 341,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67b9f4175a0637a05acbec18'),
#  'age_upon_outcome': '4 years',
#  'age_upon_outcome_in_weeks': 208.658630952381,
#  'animal_id': 'A616906',
#  'animal_type': 'Dog',
#  'breed': 'German Shepherd',
#  'color': 'Brown/Black',
#  'date_of_birth': '2010-07-01',
#  'datetime': '2014-06-30 14:39:00',
#  'location_lat': 30.2731134919741,
#  'location_long': -97.321918009823,
#  'monthyear': '2014-06-30T14:39:00',
#  'name': 'Estrella',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 346,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b9f4175a0637a05acbec19'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.9364087301587,
#  'animal_id': 'A705590',
#  'animal_type': 'Dog',
#  'breed': 'Chesapeake Bay Retriever',
#  'color': 'Black Brindle',
#  'date_of_birth': '2015-04-12',
#  'datetime': '2015-06-27 13:19:00',
#  'location_lat': 30.7083179097166,
#  'location_long': -97.3924668221853,
#  'monthyear': '2015-06-27T13:19:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 347,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b9f4175a0637a05acbec1a'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.9364087301587,
#  'animal_id': 'A705590',
#  'animal_type': 'Dog',
#  'breed': 'Rottweiler',
#  'color': 'Black/Brown',
#  'date_of_birth': '2015-04-12',
#  'datetime': '2015-06-27 13:19:00',
#  'location_lat': 30.7083179097166,
#  'location_long': -97.3924668221853,
#  'monthyear': '2015-06-27T13:19:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 357,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec1c'),
#  'age_upon_outcome': '1 year',
#  'age_upon_outcome_in_weeks': 52.2470238095238,
#  'animal_id': 'A675124',
#  'animal_type': 'Dog',
#  'breed': 'Bloodhound',
#  'color': 'Black/Brown',
#  'date_of_birth': '2013-03-23',
#  'datetime': '2014-03-23 17:30:00',
#  'location_lat': 30.397292292142,
#  'location_long': -97.305300387329,
#  'monthyear': '2014-03-23T17:30:00',
#  'name': '',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 334,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec1d'),
#  'age_upon_outcome': '3 years',
#  'age_upon_outcome_in_weeks': 156.820833333333,
#  'animal_id': 'A678393',
#  'animal_type': 'Dog',
#  'breed': 'Golden Retriever',
#  'color': 'Brown',
#  'date_of_birth': '2011-05-08',
#  'datetime': '2014-05-09 17:54:00',
#  'location_lat': 30.429299327634,
#  'location_long': -97.6161732279484,
#  'monthyear': '2014-05-09T17:54:00',
#  'name': 'Bebe',
#  'outcome_subtype': '',
#  'outcome_type': 'Return to Owner',
#  'rec_num': 315,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec1e'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 12.959623015873,
#  'animal_id': 'A746862',
#  'animal_type': 'Dog',
#  'breed': 'Doberman Pinscher',
#  'color': 'Black/Brown',
#  'date_of_birth': '2017-01-14',
#  'datetime': '2017-04-14 17:13:00',
#  'location_lat': 30.4105077089376,
#  'location_long': -97.6502521344198,
#  'monthyear': '2017-04-14T17:13:00',
#  'name': 'Harley',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 335,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec1f'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 11.212003968254,
#  'animal_id': 'A758584',
#  'animal_type': 'Dog',
#  'breed': 'Siberian Husky',
#  'color': 'White/Black',
#  'date_of_birth': '2017-09-09',
#  'datetime': '2017-11-26 11:37:00',
#  'location_lat': 30.3491408570609,
#  'location_long': -97.4793291291553,
#  'monthyear': '2017-11-26T11:37:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 336,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec20'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.478075396825,
#  'animal_id': 'A693651',
#  'animal_type': 'Dog',
#  'breed': 'Old English Sheepdog',
#  'color': 'Brown',
#  'date_of_birth': '2012-12-12',
#  'datetime': '2014-12-13 08:19:00',
#  'location_lat': 30.2891932621479,
#  'location_long': -97.5459715509776,
#  'monthyear': '2014-12-13T08:19:00',
#  'name': '',
#  'outcome_subtype': 'Rabies Risk',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 337,
#  'sex_upon_outcome': 'Unknown'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec21'),
#  'age_upon_outcome': '8 years',
#  'age_upon_outcome_in_weeks': 418.051388888889,
#  'animal_id': 'A747978',
#  'animal_type': 'Dog',
#  'breed': 'Newfoundland',
#  'color': 'Red',
#  'date_of_birth': '2009-04-27',
#  'datetime': '2017-05-01 08:38:00',
#  'location_lat': 30.4719392379806,
#  'location_long': -97.4471394988203,
#  'monthyear': '2017-05-01T08:38:00',
#  'name': '',
#  'outcome_subtype': 'Suffering',
#  'outcome_type': 'Euthanasia',
#  'rec_num': 341,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec22'),
#  'age_upon_outcome': '4 years',
#  'age_upon_outcome_in_weeks': 208.658630952381,
#  'animal_id': 'A616906',
#  'animal_type': 'Dog',
#  'breed': 'German Shepherd',
#  'color': 'Brown/Black',
#  'date_of_birth': '2010-07-01',
#  'datetime': '2014-06-30 14:39:00',
#  'location_lat': 30.2731134919741,
#  'location_long': -97.321918009823,
#  'monthyear': '2014-06-30T14:39:00',
#  'name': 'Estrella',
#  'outcome_subtype': 'Partner',
#  'outcome_type': 'Transfer',
#  'rec_num': 346,
#  'sex_upon_outcome': 'Spayed Female'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec23'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.9364087301587,
#  'animal_id': 'A705590',
#  'animal_type': 'Dog',
#  'breed': 'Chesapeake Bay Retriever',
#  'color': 'Black Brindle',
#  'date_of_birth': '2015-04-12',
#  'datetime': '2015-06-27 13:19:00',
#  'location_lat': 30.7083179097166,
#  'location_long': -97.3924668221853,
#  'monthyear': '2015-06-27T13:19:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 347,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67b9f68a5a0637a05acbec24'),
#  'age_upon_outcome': '2 months',
#  'age_upon_outcome_in_weeks': 10.9364087301587,
#  'animal_id': 'A705590',
#  'animal_type': 'Dog',
#  'breed': 'Rottweiler',
#  'color': 'Black/Brown',
#  'date_of_birth': '2015-04-12',
#  'datetime': '2015-06-27 13:19:00',
#  'location_lat': 30.7083179097166,
#  'location_long': -97.3924668221853,
#  'monthyear': '2015-06-27T13:19:00',
#  'name': '',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 357,
#  'sex_upon_outcome': 'Neutered Male'}
# {'_id': ObjectId('67ba1d1c5a0637a05acbec78'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Labrador Retriever Mix',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Mia',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67ba1d315a0637a05acbec7a'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Chesapeake Bay Retriever',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Mia',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67ba1d405a0637a05acbec7c'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Newfoundland',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Mia',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Female'}
# {'_id': ObjectId('67ba1d6b5a0637a05acbec7e'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'German Shepherd',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67ba1d7c5a0637a05acbec80'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Alaskan Malamute',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67ba1d8e5a0637a05acbec82'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Old English Sheepdog',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67ba1d9d5a0637a05acbec84'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Siberian Husky',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67ba1dab5a0637a05acbec86'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Rottweiler',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67ba1dbf5a0637a05acbec88'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Doberman Pinscher',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67ba1dd45a0637a05acbec8a'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Golden Retriever',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
# {'_id': ObjectId('67ba1de65a0637a05acbec8c'),
#  'age_upon_outcome': '2 years',
#  'age_upon_outcome_in_weeks': 104.393948412698,
#  'animal_id': 'A730354',
#  'animal_type': 'Dog',
#  'breed': 'Bloodhound',
#  'color': 'Blue/White',
#  'date_of_birth': '2015-07-02',
#  'datetime': '2017-07-01 18:11:00',
#  'location_lat': 30.4815689674138,
#  'location_long': -97.3694960927915,
#  'monthyear': '2017-07-01T18:11:00',
#  'name': 'Louis',
#  'outcome_subtype': '',
#  'outcome_type': 'Adoption',
#  'rec_num': 21,
#  'sex_upon_outcome': 'Intact Male'}
